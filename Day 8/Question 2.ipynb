# %%
print('Question 2. For this challenge you need to develop a Python program to open a file in read only mode and try writing something to it and handle the subsequent errors using Exception Handling.')

# %%writefile test.txt
Hi this is ASAD

# %%
try:
    file = open("test.txt","r")
    file.write("\nI am from Bihar.")
    print("\nWrite operation has done successfully in read only mode.")
except Exception as e:
    print("\nError occured")
    print("\nError message is :",e)
